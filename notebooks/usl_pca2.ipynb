# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.decomposition import PCA
from sklearn.feature_selection import mutual_info_regression

from matplotlib import style

# %%
# matplotlib defaults

plt.style.use("seaborn-v0_8-dark")
plt.rc("figure", autolayout=True)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=14,
    titlepad=10,
)

# %%
# matplotlib defaults
from google.colab import drive
drive.mount('/content/drive')

cara = pd.read_csv('/content/drive/MyDrive/UniTS/CodeProjects/Unsupervised_Learning/data/cara.csv')
cara
# Out:
# Mounted at /content/drive
#          model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7
# 1        Focus  2018  14000       Manual     9083   Petrol  150  57.7
# 2        Focus  2017  13000       Manual    12456   Petrol  150  57.7
# 3       Fiesta  2019  17500       Manual    10460   Petrol  145  40.3
# 4       Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7
# ...        ...   ...    ...          ...      ...      ...  ...   ...
# 17960   Fiesta  2016   7999       Manual    31348   Petrol  125  54.3
# 17961    B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962    B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963    Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964       KA  2018   8299       Manual     5007   Petrol  145  57.7
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# ...

# %%
num_dims = [dim for dim in cara.columns if cara[dim].dtype in ['int64', 'float64']]

cara[num_dims].var().sort_values()
# Out:
# engineSize    1.869450e-01
# year          4.203918e+00
# mpg           1.025354e+02
# tax           3.845294e+03
# price         2.248071e+07
# mileage       3.791633e+08
# dtype: float64

# %%
for idx, col in enumerate(num_dims):
  plt.figure(idx, figsize=(4,4))
  sns.scatterplot(x=col, y='price', data=cara)
  plt.show

# %%
y = [73,95,57,110,89]

# %%
y1 = [(d-np.min(y))/(np.max(y) - np.min(y)) for d in y ]
y2 = [(d-np.mean(y)) /np.std(y) for d in y ]

# %%
57-np.min(y)/(np.max(y) - np.min(y))
# Out:
# 55.924528301886795

# %%
np.std(y)
# Out:
# 18.269099594670777

# %%
y1_back = [(d * (np.max(y) - np.min(y))) + np.min(y) for d in y1 ]
y1_back
# Out:
# [73.0, 95.0, 57.0, 110.0, 89.0]

# %%
plt.figure(1, figsize=(4,4))
sns.lineplot(y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(1, figsize=(4,4))
sns.lineplot(y1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(1, figsize=(4,4))
sns.lineplot(y2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
